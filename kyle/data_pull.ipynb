# %% [markdown]
# # Packages and Helper Functions

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import polars as pl
import scipy.stats as stats
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm
import matplotlib.pyplot as plt
import math

from data_funcs import *

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.float_format', lambda x: "%.4f" % x)
# pd.options.plotting.backend = "plotly"

plt.style.use('ggplot')
sns.set_style('darkgrid')

# %% [markdown]
# # Reading in Data

# %%
data_tuples = [
    (1718, "owg2018", "https://results.isu.org/results/season1718/owg2018/"),
    (1718, "ec2018", "https://results.isu.org/results/season1718/ec2018/"),
    (1718, "wc2018", "https://results.isu.org/results/season1718/wc2018/"), 
    (1718, "fc2018", "https://www.isuresults.com/results/season1718/fc2018/"), 
    (1718, "gpcan2017", "https://www.isuresults.com/results/season1718/gpcan2017/"),
    (1718, "gpusa2017", "https://www.isuresults.com/results/season1718/gpusa2017/"),
    (1718, "gpfra2017", "https://www.isuresults.com/results/season1718/gpfra2017/"),
    (1718, "gpf1718", "https://www.isuresults.com/results/season1718/gpf1718/"), 

    (1819, "ec2019","https://www.isuresults.com/results/season1819/ec2019/"),
    (1819, "wc2019","https://www.isuresults.com/results/season1819/wc2019/"),    
    (1819, "fc2019","https://www.isuresults.com/results/season1819/fc2019/"),  
    (1819, "gpcan2018", "https://www.isuresults.com/results/season1819/gpcan2018/"),
    (1819, "gpusa2018", "https://www.isuresults.com/results/season1819/gpusa2018/"),
    (1819, "gpfra2018", "https://www.isuresults.com/results/season1819/gpfra2018/"),
    (1819, "gpf1819", "https://www.isuresults.com/results/season1819/gpf1819/"),

    (1920, "ec2020", "https://www.isuresults.com/results/season1920/ec2020/"),
    # (1920, "wc2020", "https://www.isuresults.com/results/season1920/wc2020/"),
    (1920, "fc2020", "https://www.isuresults.com/results/season1920/fc2020/"),
    (1920, "gpcan2019", "https://www.isuresults.com/results/season1920/gpcan2019/"),
    (1920, "gpusa2019", "https://www.isuresults.com/results/season1920/gpusa2019/"),
    (1920, "gpfra2019", "https://www.isuresults.com/results/season1920/gpfra2019/"),
    (1920, "gpf1920", "https://www.isuresults.com/results/season1920/gpf1920/"),

    (2021, "wc2021", "https://www.isuresults.com/results/season2021/wc2021/"),
    
    (2122, "ec2022", "https://www.isuresults.com/results/season2122/ec2022/"),
    (2122, "wc2022", "https://www.isuresults.com/results/season2122/wc2022/"),
    (2122, "fc2022", "https://www.isuresults.com/results/season2122/fc2022/"),
    (2122, "gpcan2021", "https://results.isu.org/results/season2122/gpcan2021/"),
    (2122, "gpusa2021", "https://www.isuresults.com/results/season2122/gpusa2021/"),
    (2122, "gpfra2021", "https://www.isuresults.com/results/season2122/gpfra2021/"),
    (2122, "owg2022", "https://results.isu.org/results/season2122/owg2022/"),

    (2223, "ec2023", "https://www.isuresults.com/results/season2223/ec2023/"),
    (2223, "wc2023", "https://www.isuresults.com/results/season2223/wc2023/"), 
    (2223, "fc2023", "https://www.isuresults.com/results/season2223/fc2023/"), 
    (2223, "gpcan2022", "https://www.isuresults.com/results/season2223/gpcan2022/"),
    (2223, "gpusa2022", "https://www.isuresults.com/results/season2223/gpusa2022/"),
    (2223, "gpfra2022", "https://www.isuresults.com/results/season2223/gpfra2022/"),

    (2324, "ec2024", "https://www.isuresults.com/results/season2324/ec2024/"),
    (2324, "wc2024", "https://www.isuresults.com/results/season2324/wc2024/"), 
    (2324, "fc2024", "https://www.isuresults.com/results/season2324/fc2024/"), 
    (2324, "gpcan2023", "https://www.isuresults.com/results/season2324/gpcan2023/"),
    (2324, "gpusa2023", "https://www.isuresults.com/results/season2324/gpusa2023/"),
    (2324, "gpfra2023", "https://www.isuresults.com/results/season2324/gpfra2023/"),

    (2425, "ec2025", "https://www.isuresults.com/results/season2425/ec2025/"),
    (2425, "wc2025", "https://www.isuresults.com/results/season2425/wc2025/"), 
    (2425, "fc2025", "https://www.isuresults.com/results/season2425/fc2025/"), 
    (2425, "gpcan2024", "https://www.isuresults.com/results/season2425/gpcan2024/"),
    (2425, "gpusa2024", "https://www.isuresults.com/results/season2425/gpusa2024/"),
    (2425, "gpfra2024", "https://www.isuresults.com/results/season2425/gpfra2024/"),

    (2526, "gpcan2025", "https://www.isuresults.com/results/season2526/gpcan2025/"),
    (2526, "gpusa2025", "https://www.isuresults.com/results/season2526/gpusa2025/"),
    (2526, "gpfra2025", "https://www.isuresults.com/results/season2526/gpfra2025/"),
]

# %%
for isu_year, isu_event, isu_url in data_tuples:
    ret_val = process_data(isu_year, isu_event, isu_url)
# Out:
# data directory already exists: ./owg2018
# PROCESSING owg2018...
# PROCESSING JUDGES...
# Added 144 judges to ./judge_nationalities.csv
# PROCESSING OWG2018_TeamIceDance_SD_D_Scores.pdf...
# DONE
# -------------------
# PROCESSING OWG2018_TeamMen_SP_M_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_LadiesSingleSkating_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamLadies_SP_F_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamIceDance_FD_D_Scores.pdf...
# DONE
# -------------------
# PROCESSING OWG2018_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING OWG2018_MenSingleSkating_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_PairSkating_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamPairs_SP_P_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING OWG2018_LadiesSingleSkating_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamPairs_FS_P_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_MenSingleSkating_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamLadies_FS_F_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_TeamMen_FS_M_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING OWG2018_PairSkating_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2716 rows to ./owg2018/owg2018.csv
# -------------------
# data directory already exists: ./ec2018
# PROCESSING ec2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING ec2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2018_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING ec2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING ec2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2140 rows to ./ec2018/ec2018.csv
# -------------------
# data directory already exists: ./wc2018
# PROCESSING wc2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING wc2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING wc2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING wc2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# Saved 2313 rows to ./wc2018/wc2018.csv
# -------------------
# data directory already exists: ./fc2018
# PROCESSING fc2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING fc2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING fc2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2018_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING fc2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1744 rows to ./fc2018/fc2018.csv
# -------------------
# data directory already exists: ./gpcan2017
# PROCESSING gpcan2017...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpcan2017_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2017_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2017_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2017_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2017_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2017_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpcan2017_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpcan2017_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 934 rows to ./gpcan2017/gpcan2017.csv
# -------------------
# data directory already exists: ./gpusa2017
# PROCESSING gpusa2017...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpusa2017_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2017_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2017_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2017_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2017_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpusa2017_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpusa2017_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2017_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 852 rows to ./gpusa2017/gpusa2017.csv
# -------------------
# data directory already exists: ./gpfra2017
# PROCESSING gpfra2017...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpfra2017_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2017_IceDance_SD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpfra2017_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2017_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2017_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpfra2017_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2017_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2017_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 875 rows to ./gpfra2017/gpfra2017.csv
# -------------------
# data directory already exists: ./gpf1718
# PROCESSING gpf1718...
# PROCESSING JUDGES...
# Added 0 judges to ./judge_nationalities.csv
# Saved 0 rows to ./gpf1718/gpf1718.csv
# -------------------
# data directory already exists: ./ec2019
# PROCESSING ec2019...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING ec2019_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2019_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2019_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING ec2019_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2019_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2019_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING ec2019_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING ec2019_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1978 rows to ./ec2019/ec2019.csv
# -------------------
# data directory already exists: ./wc2019
# PROCESSING wc2019...
# PROCESSING JUDGES...
# Added 0 judges to ./judge_nationalities.csv
# Saved 0 rows to ./wc2019/wc2019.csv
# -------------------
# data directory already exists: ./fc2019
# PROCESSING fc2019...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING fc2019_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2019_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING fc2019_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2019/fc2019_Pairs_SP_Scores.pdf
# DONE
# -------------------
# PROCESSING fc2019_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2019_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING fc2019_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING fc2019_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2019/fc2019_Pairs_FS_Scores.pdf
# DONE
# -------------------
# PROCESSING fc2019_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1324 rows to ./fc2019/fc2019.csv
# -------------------
# data directory already exists: ./gpcan2018
# PROCESSING gpcan2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpcan2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2018_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpcan2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpcan2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpcan2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 885 rows to ./gpcan2018/gpcan2018.csv
# -------------------
# data directory already exists: ./gpusa2018
# PROCESSING gpusa2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpusa2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2018_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpusa2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpusa2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpusa2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 868 rows to ./gpusa2018/gpusa2018.csv
# -------------------
# data directory already exists: ./gpfra2018
# PROCESSING gpfra2018...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING gpfra2018_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpfra2018_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpfra2018_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# Saved 840 rows to ./gpfra2018/gpfra2018.csv
# -------------------
# data directory already exists: ./gpf1819
# PROCESSING gpf1819...
# PROCESSING JUDGES...
# Added 144 judges to ./judge_nationalities.csv
# PROCESSING gpf1819_IceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorPairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_Ladies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorIceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorLadies_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorMen_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_Men_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_Pairs_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorIceDance_FD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpf1819_Ladies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorPairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_IceDance_RD_Scores.pdf...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorLadies_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_Men_FS_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_Pairs_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING gpf1819_JuniorMen_SP_Scores.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 987 rows to ./gpf1819/gpf1819.csv
# -------------------
# data directory already exists: ./ec2020
# PROCESSING ec2020...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2152 rows to ./ec2020/ec2020.csv
# -------------------
# data directory already exists: ./fc2020
# PROCESSING fc2020...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2020/FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2020/FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 972 rows to ./fc2020/fc2020.csv
# -------------------
# data directory already exists: ./gpcan2019
# PROCESSING gpcan2019...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 920 rows to ./gpcan2019/gpcan2019.csv
# -------------------
# data directory already exists: ./gpusa2019
# PROCESSING gpusa2019...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 920 rows to ./gpusa2019/gpusa2019.csv
# -------------------
# data directory already exists: ./gpfra2019
# PROCESSING gpfra2019...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 862 rows to ./gpfra2019/gpfra2019.csv
# -------------------
# data directory already exists: ./gpf1920
# PROCESSING gpf1920...
# PROCESSING JUDGES...
# Added 144 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-JUNIOR----QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-JUNIOR----QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-JUNIOR----FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-JUNIOR----FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCEJUNIOR----QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCEJUNIOR----FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS---JUNIOR----FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS---JUNIOR----QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1014 rows to ./gpf1920/gpf1920.csv
# -------------------
# data directory already exists: ./wc2021
# PROCESSING wc2021...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2264 rows to ./wc2021/wc2021.csv
# -------------------
# data directory already exists: ./ec2022
# PROCESSING ec2022...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2135 rows to ./ec2022/ec2022.csv
# -------------------
# data directory already exists: ./wc2022
# PROCESSING wc2022...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1903 rows to ./wc2022/wc2022.csv
# -------------------
# data directory already exists: ./fc2022
# PROCESSING fc2022...
# PROCESSING JUDGES...
# Added 64 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2022/FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2022/FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2022/FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# FAILED ./fc2022/FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf
# DONE
# -------------------
# Saved 580 rows to ./fc2022/fc2022.csv
# -------------------
# data directory already exists: ./gpcan2021
# PROCESSING gpcan2021...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 920 rows to ./gpcan2021/gpcan2021.csv
# -------------------
# data directory already exists: ./gpusa2021
# PROCESSING gpusa2021...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 874 rows to ./gpusa2021/gpusa2021.csv
# -------------------
# data directory already exists: ./gpfra2021
# PROCESSING gpfra2021...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 891 rows to ./gpfra2021/gpfra2021.csv
# -------------------
# data directory already exists: ./owg2022
# PROCESSING owg2022...
# PROCESSING JUDGES...
# Added 144 judges to ./judge_nationalities.csv
# PROCESSING FSKXTEAM--------------FNL-0002LD--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------QUAL0002LD--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------QUAL0001MN--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------FNL-0001MN--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------QUAL0004DC--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------FNL-0004DC--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------QUAL0003PR--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXTEAM--------------FNL-0003PR--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 2698 rows to ./owg2022/owg2022.csv
# -------------------
# data directory already exists: ./ec2023
# PROCESSING ec2023...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1480 rows to ./ec2023/ec2023.csv
# -------------------
# data directory already exists: ./wc2023
# PROCESSING wc2023...
# PROCESSING JUDGES...
# Added 0 judges to ./judge_nationalities.csv
# Saved 0 rows to ./wc2023/wc2023.csv
# -------------------
# data directory already exists: ./fc2023
# PROCESSING fc2023...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1214 rows to ./fc2023/fc2023.csv
# -------------------
# data directory already exists: ./gpcan2022
# PROCESSING gpcan2022...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 692 rows to ./gpcan2022/gpcan2022.csv
# -------------------
# data directory already exists: ./gpusa2022
# PROCESSING gpusa2022...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 714 rows to ./gpusa2022/gpusa2022.csv
# -------------------
# data directory already exists: ./gpfra2022
# PROCESSING gpfra2022...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 692 rows to ./gpfra2022/gpfra2022.csv
# -------------------
# data directory already exists: ./ec2024
# PROCESSING ec2024...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1614 rows to ./ec2024/ec2024.csv
# -------------------
# data directory already exists: ./wc2024
# PROCESSING wc2024...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1823 rows to ./wc2024/wc2024.csv
# -------------------
# data directory already exists: ./fc2024
# PROCESSING fc2024...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1413 rows to ./fc2024/fc2024.csv
# -------------------
# data directory already exists: ./gpcan2023
# PROCESSING gpcan2023...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 728 rows to ./gpcan2023/gpcan2023.csv
# -------------------
# data directory already exists: ./gpusa2023
# PROCESSING gpusa2023...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 706 rows to ./gpusa2023/gpusa2023.csv
# -------------------
# data directory already exists: ./gpfra2023
# PROCESSING gpfra2023...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 715 rows to ./gpfra2023/gpfra2023.csv
# -------------------
# data directory already exists: ./ec2025
# PROCESSING ec2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1587 rows to ./ec2025/ec2025.csv
# -------------------
# data directory already exists: ./wc2025
# PROCESSING wc2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1755 rows to ./wc2025/wc2025.csv
# -------------------
# data directory already exists: ./fc2025
# PROCESSING fc2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 1207 rows to ./fc2025/fc2025.csv
# -------------------
# data directory already exists: ./gpcan2024
# PROCESSING gpcan2024...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 695 rows to ./gpcan2024/gpcan2024.csv
# -------------------
# data directory already exists: ./gpusa2024
# PROCESSING gpusa2024...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 716 rows to ./gpusa2024/gpusa2024.csv
# -------------------
# data directory already exists: ./gpfra2024
# PROCESSING gpfra2024...
# PROCESSING JUDGES...
# Added 70 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 707 rows to ./gpfra2024/gpfra2024.csv
# -------------------
# data directory already exists: ./gpcan2025
# PROCESSING gpcan2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 717 rows to ./gpcan2025/gpcan2025.csv
# -------------------
# data directory already exists: ./gpusa2025
# PROCESSING gpusa2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 712 rows to ./gpusa2025/gpusa2025.csv
# -------------------
# data directory already exists: ./gpfra2025
# PROCESSING gpfra2025...
# PROCESSING JUDGES...
# Added 72 judges to ./judge_nationalities.csv
# PROCESSING FSKMSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKMSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKWSINGLES-----------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------FNL-000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXICEDANCE----------QUAL000100--_JudgesDetailsperSkater.pdf...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------QUAL000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# PROCESSING FSKXPAIRS-------------FNL-000100--_JudgesDetailsperSkater.pdf...
# VALID SCORE SHEET...
# DONE
# -------------------
# Saved 713 rows to ./gpfra2025/gpfra2025.csv
# -------------------

# %%
# def _flip_name(name):
#     if not isinstance(name, str):
#         return name
#     parts = name.split()
#     if len(parts) == 2:
#         return f"{parts[1]} {parts[0]}"
#     return name

# judge_csv_path = "./judge_nationalities.csv"
# judge_df = pd.read_csv(judge_csv_path)
# isu_mask = judge_df["judge_nationality"] == "ISU"

# non_isu = (
#     judge_df.loc[~isu_mask, ["judge_name", "judge_nationality"]]
#     .drop_duplicates("judge_name")
# )

# name_to_nat = non_isu.set_index("judge_name")["judge_nationality"]

# flipped_to_nat = (
#     non_isu.assign(judge_name=non_isu["judge_name"].map(_flip_name))
#     .set_index("judge_name")["judge_nationality"]
# )

# # Fill ISU rows using exact match, then flipped match, else keep ISU
# judge_df.loc[isu_mask, "judge_nationality"] = (
#     judge_df.loc[isu_mask, "judge_name"]
#         .map(name_to_nat)
#         .fillna(
#             judge_df.loc[isu_mask, "judge_name"]
#                 .map(flipped_to_nat)
#         )
#         .fillna("ISU")
# )
# judge_df.to_csv(judge_csv_path, index=False)
